# %% [markdown]
# We compare the distributions of the statistics of the semi continuous brunel model with the continuous model. That is, the model where everything is continuous except the delay values. The probability of each delay value is equal.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (14, 10)
import numpy as np
from scipy.stats import probplot
from scipy.stats import normaltest
from matplotlib import cm

# %%
df_01 = pd.read_pickle('structured_df.pkl') # droop, equal and cont model statistics
df_02 = pd.read_pickle('C:\\Users\\Nida\\Documents\\NMBU\\master\\organized_spike_data\\semi_cont_brunel_df.pkl') # semi cont model statistics

# %% [markdown]
# # CV distributions
#
# Plt the semi cont brunel CV distributions for all resolutions together with the continuous model.

# %%
for i in range(1,11):
    cv = df_02.loc[2,i]['CV']
    sns.ecdfplot(cv,color='r')
    
for i in range(1,11):
    cv = df_02.loc[4,i]['CV']
    sns.ecdfplot(cv,color='g')
    
for i in range(1,11):
    cv = df_02.loc[8,i]['CV']
    sns.ecdfplot(cv,color='b')
    
for i in range(1,11):
    cv = df_02.loc[16,i]['CV']
    sns.ecdfplot(cv,color='m')
    
for i in range(1,11):
    cv = df_02.loc[32,i]['CV']
    sns.ecdfplot(cv,color='c')
    
for i in range(1,11):
    cv = df_02.loc[64,i]['CV']
    sns.ecdfplot(cv,color='k')
    
for i in range(1,11):
    cv = df_02.loc[128,i]['CV']
    sns.ecdfplot(cv,color='y')
    
for i in range(1,11):
    cv = df_02.loc[256,i]['CV']
    sns.ecdfplot(cv,color='gold')
    
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color='aqua')

# %% [markdown]
# Now plot for one resolution at the time and compare to the continuous model CV distribution.

# %%
n=2
colors = plt.cm.viridis(np.linspace(0, 1, n))

# %%
for i in range(1,11):
    cv = df_02.loc[2,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/2');

# %% [markdown]
# We see a difference in the two models, however the distance is not that great compared to the case of the droop and equal models seen earlier.

# %%
for i in range(1,11):
    cv = df_02.loc[4,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/4');

# %% [markdown]
# We can still see a difference between the two models, but looks like the lines are starting to overlap slightly, plot a zoomed in version.

# %%
for i in range(1,11):
    cv = df_02.loc[4,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/4');
plt.xlim(0.17,0.19);
plt.ylim(0.4,0.8);

# %%
for i in range(1,11):
    cv = df_02.loc[8,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/8');

# %% [markdown]
# More overlapping here, but still the semi cont model (purple)is more to the left than the continuous one.

# %%
for i in range(1,11):
    cv = df_02.loc[16,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/16');

# %% [markdown]
# Now it looks like the models are very similar, mostly overlapping lines.

# %%
for i in range(1,11):
    cv = df_02.loc[32,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/32');

# %% [markdown]
# A litlle spread out lines, but not one model more to one side than the other.

# %%
for i in range(1,11):
    cv = df_02.loc[64,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/64');

# %% [markdown]
# Very similar.

# %%
for i in range(1,11):
    cv = df_02.loc[128,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/128');

# %%
for i in range(1,11):
    cv = df_02.loc[256,i]['CV']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CV']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/256');

# %% [markdown]
# Looks like as resolution reaches 1/16 the two models are quite equal according to their CV distributions. Lets look into the FR distributions.
#
# # FR distributions

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[2,i]['FR']]
    sns.ecdfplot(fr,color='r')
    
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[4,i]['FR']]
    sns.ecdfplot(fr,color='g')
    
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[8,i]['FR']]
    sns.ecdfplot(fr,color='b')
    
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[16,i]['FR']]
    sns.ecdfplot(fr,color='m')
    
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[32,i]['FR']]
    sns.ecdfplot(fr,color='c')
    
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[64,i]['FR']]
    sns.ecdfplot(fr,color='k')
    
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[128,i]['FR']]
    sns.ecdfplot(fr,color='y')
    
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[256,i]['FR']]
    sns.ecdfplot(fr,color='gold')
    
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color='aqua')

# %% [markdown]
# One resolution at a time:

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[2,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/2');

# %% [markdown]
# Seems like the semi cont model (purple) lines are slightly more to the right, see a small difference between the two models.

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[4,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/4');

# %% [markdown]
# Now there does not seem to be such a difference.

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[8,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/8');

# %% [markdown]
# No clear trend of one model being more to one side than the other, but the lines are quite spread out.

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[16,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/16');

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[32,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/32');

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[64,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/64');

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[128,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/128');

# %%
for i in range(1,11):
    fr = [float(x) for x in df_02.loc[256,i]['FR']]
    sns.ecdfplot(fr,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    fr = [float(x) for x in df_01.loc['continuous',8,i]['FR']]
    sns.ecdfplot(fr,color=colors[1],alpha=0.5)

plt.title('Resolution 1/256');

# %% [markdown]
# It is slightly harder to compare the lines of these step-like plots, but seemed like for resolution larger than 1/2, the models seemed to be quite equal.
#
# # CC distributions
#
# ## 5ms binsize

# %%
for i in range(1,11):
    cc = df_02.loc[2,i]['CC_5']
    sns.ecdfplot(cc,color='r')
    
for i in range(1,11):
    cc = df_02.loc[4,i]['CC_5']
    sns.ecdfplot(cc,color='g')
    
for i in range(1,11):
    cc = df_02.loc[8,i]['CC_5']
    sns.ecdfplot(cc,color='b')
    
for i in range(1,11):
    cc = df_02.loc[16,i]['CC_5']
    sns.ecdfplot(cc,color='m')
    
for i in range(1,11):
    cc = df_02.loc[32,i]['CC_5']
    sns.ecdfplot(cc,color='c')
    
for i in range(1,11):
    cc = df_02.loc[64,i]['CC_5']
    sns.ecdfplot(cc,color='k')
    
for i in range(1,11):
    cc = df_02.loc[128,i]['CC_5']
    sns.ecdfplot(cc,color='y')
    
for i in range(1,11):
    cc = df_02.loc[256,i]['CC_5']
    sns.ecdfplot(cc,color='gold')
    
    
# plot the true values
for i in range(1,11):
    cc = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cc,color='aqua')

# %%
for i in range(1,11):
    cv = df_02.loc[2,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/2');

# %%
for i in range(1,11):
    cv = df_02.loc[4,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/4');

# %%
for i in range(1,11):
    cv = df_02.loc[8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/8');

# %%
for i in range(1,11):
    cv = df_02.loc[16,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/16');

# %%
for i in range(1,11):
    cv = df_02.loc[32,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/32');

# %%
for i in range(1,11):
    cv = df_02.loc[64,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/64');

# %%
for i in range(1,11):
    cv = df_02.loc[128,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/128');

# %%
for i in range(1,11):
    cv = df_02.loc[256,i]['CC_5']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_5']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/256');

# %% [markdown]
# No clear distinction between the two models for any of the resolutions according to the CC distributions when binsize 5ms was used. Lets examine the others.
#
# ## 10ms binsize

# %%
for i in range(1,11):
    cc = df_02.loc[2,i]['CC_10']
    sns.ecdfplot(cc,color='r')
    
for i in range(1,11):
    cc = df_02.loc[4,i]['CC_10']
    sns.ecdfplot(cc,color='g')
    
for i in range(1,11):
    cc = df_02.loc[8,i]['CC_10']
    sns.ecdfplot(cc,color='b')
    
for i in range(1,11):
    cc = df_02.loc[16,i]['CC_10']
    sns.ecdfplot(cc,color='m')
    
for i in range(1,11):
    cc = df_02.loc[32,i]['CC_10']
    sns.ecdfplot(cc,color='c')
    
for i in range(1,11):
    cc = df_02.loc[64,i]['CC_10']
    sns.ecdfplot(cc,color='k')
    
for i in range(1,11):
    cc = df_02.loc[128,i]['CC_10']
    sns.ecdfplot(cc,color='y')
    
for i in range(1,11):
    cc = df_02.loc[256,i]['CC_10']
    sns.ecdfplot(cc,color='gold')
    
    
# plot the true values
for i in range(1,11):
    cc = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cc,color='aqua')

# %%
for i in range(1,11):
    cv = df_02.loc[2,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/2');

# %%
for i in range(1,11):
    cv = df_02.loc[4,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/4');

# %%
for i in range(1,11):
    cv = df_02.loc[8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/8');

# %%
for i in range(1,11):
    cv = df_02.loc[16,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/16');

# %%
for i in range(1,11):
    cv = df_02.loc[32,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/32');

# %%
for i in range(1,11):
    cv = df_02.loc[64,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/64');

# %%
for i in range(1,11):
    cv = df_02.loc[128,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/128');

# %%
for i in range(1,11):
    cv = df_02.loc[256,i]['CC_10']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_10']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/256');

# %% [markdown]
# Once again, no clear distinction between the two models accoridng to their CC distributions with 10 ms binsize.
#
# ## 20ms binsize

# %%
for i in range(1,11):
    cc = df_02.loc[2,i]['CC_20']
    sns.ecdfplot(cc,color='r')
    
for i in range(1,11):
    cc = df_02.loc[4,i]['CC_20']
    sns.ecdfplot(cc,color='g')
    
for i in range(1,11):
    cc = df_02.loc[8,i]['CC_20']
    sns.ecdfplot(cc,color='b')
    
for i in range(1,11):
    cc = df_02.loc[16,i]['CC_20']
    sns.ecdfplot(cc,color='m')
    
for i in range(1,11):
    cc = df_02.loc[32,i]['CC_20']
    sns.ecdfplot(cc,color='c')
    
for i in range(1,11):
    cc = df_02.loc[64,i]['CC_20']
    sns.ecdfplot(cc,color='k')
    
for i in range(1,11):
    cc = df_02.loc[128,i]['CC_20']
    sns.ecdfplot(cc,color='y')
    
for i in range(1,11):
    cc = df_02.loc[256,i]['CC_20']
    sns.ecdfplot(cc,color='gold')
    
    
# plot the true values
for i in range(1,11):
    cc = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cc,color='aqua')

# %%
for i in range(1,11):
    cv = df_02.loc[2,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/2');

# %%
for i in range(1,11):
    cv = df_02.loc[4,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/4');

# %%
for i in range(1,11):
    cv = df_02.loc[8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/8');

# %%
for i in range(1,11):
    cv = df_02.loc[16,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/16');

# %%
for i in range(1,11):
    cv = df_02.loc[32,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/32');

# %%
for i in range(1,11):
    cv = df_02.loc[64,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/64');

# %%
for i in range(1,11):
    cv = df_02.loc[128,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/128');

# %%
for i in range(1,11):
    cv = df_02.loc[256,i]['CC_20']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_20']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/256');

# %% [markdown]
# No clear distinction between the two models.
#
# ## 50ms binsize

# %%
for i in range(1,11):
    cc = df_02.loc[2,i]['CC_50']
    sns.ecdfplot(cc,color='r')
    
for i in range(1,11):
    cc = df_02.loc[4,i]['CC_50']
    sns.ecdfplot(cc,color='g')
    
for i in range(1,11):
    cc = df_02.loc[8,i]['CC_50']
    sns.ecdfplot(cc,color='b')
    
for i in range(1,11):
    cc = df_02.loc[16,i]['CC_50']
    sns.ecdfplot(cc,color='m')
    
for i in range(1,11):
    cc = df_02.loc[32,i]['CC_50']
    sns.ecdfplot(cc,color='c')
    
for i in range(1,11):
    cc = df_02.loc[64,i]['CC_50']
    sns.ecdfplot(cc,color='k')
    
for i in range(1,11):
    cc = df_02.loc[128,i]['CC_50']
    sns.ecdfplot(cc,color='y')
    
for i in range(1,11):
    cc = df_02.loc[256,i]['CC_50']
    sns.ecdfplot(cc,color='gold')
    
    
# plot the true values
for i in range(1,11):
    cc = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cc,color='aqua')

# %%
for i in range(1,11):
    cv = df_02.loc[2,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/2');

# %%
for i in range(1,11):
    cv = df_02.loc[4,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/4');

# %%
for i in range(1,11):
    cv = df_02.loc[8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/8');

# %%
for i in range(1,11):
    cv = df_02.loc[16,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/16');

# %%
for i in range(1,11):
    cv = df_02.loc[32,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/32');

# %%
for i in range(1,11):
    cv = df_02.loc[64,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/64');

# %%
for i in range(1,11):
    cv = df_02.loc[128,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/128');

# %%
for i in range(1,11):
    cv = df_02.loc[256,i]['CC_50']
    sns.ecdfplot(cv,color=colors[0],alpha=0.5)
    
# plot the true values
for i in range(1,11):
    cv = df_01.loc['continuous',8,i]['CC_50']
    sns.ecdfplot(cv,color=colors[1],alpha=0.5)

plt.title('Resolution 1/256');

# %% [markdown]
# No clear distinction between the two models.
